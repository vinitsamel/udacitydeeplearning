# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is that probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter
import random

threshold = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)
freqs = {word: count/total_count for word, count in word_counts.items()}
p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}
train_words = [word for word in int_words if random.random() < (1 - p_drop[word])]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you chose a random number of words to from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    R = np.random.randint(1, window_size+1)
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as one-hot encoded vectors. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1))
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, 
                                      labels, embed,
                                      n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6393 0.2073 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6415 0.2260 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.5393 0.2468 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5864 0.2465 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5078 0.2456 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5876 0.2385 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5494 0.2104 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5270 0.2313 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4635 0.2221 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4237 0.2471 sec/batch
# Nearest to this: gravity, panic, authorised, residing, forcible, stabilized, subjugated, helpful,
# Nearest to but: affixed, stricter, mok, jen, crossroads, harker, avalokitesvara, imap,
# Nearest to d: constructors, wadb, holloway, phylogenetics, uv, divan, dogbert, webs,
# Nearest to to: inspect, vampyre, freak, hort, polyphony, ean, wheelock, intercept,
# Nearest to time: gms, contraindications, taland, licensed, besieges, persistence, astm, muzorewa,
# Nearest to up: dealings, recollections, schwartz, rebus, assaulted, kaunda, gelling, docklands,
# Nearest to or: stuntman, plausible, snuck, ascertain, theologically, franchises, sempron, aarhus,
# Nearest to is: cessna, fulcrum, seems, absurdity, lullaby, desai, magellanic, radiochemical,
# Nearest to pope: ipo, milking, illicit, monkees, mesoderm, tartaric, hollis, ran,
# Nearest to orthodox: burnaby, projectors, titan, geochemistry, refrained, herbicides, anthropocentric, keener,
# Nearest to channel: jarmann, truthfully, grunge, fairway, hardwicke, fermi, convenient, erectile,
# Nearest to active: gothicus, awa, ibo, sintering, jass, caches, perses, rugrats,
# Nearest to award: assert, cohen, discard, backup, caster, methylphenidate, teslas, grenfell,
# Nearest to primarily: kcal, torrens, selling, functions, rehabilitate, learners, preferring, sybase,
# Nearest to cost: cal, instated, thoroughbred, politic, contingencies, result, punchline, ringo,
# Nearest to magazine: hyena, ekg, blueprint, joliot, softball, plotted, translate, reflectors,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4732 0.2166 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3944 0.2195 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3139 0.2213 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2422 0.2264 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1851 0.2060 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1824 0.1963 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.0936 0.1968 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0727 0.2245 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0011 0.2186 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9950 0.2180 sec/batch
# Nearest to this: gravity, panic, residing, authorised, helpful, legitimacy, revived, forcible,
# Nearest to but: days, equally, imply, stricter, purposes, affixed, burst, crossroads,
# Nearest to d: ceded, holloway, uv, constructors, looking, eugene, years, teachers,
# Nearest to to: inspect, repeated, promise, better, freak, of, york, newspapers,
# Nearest to time: licensed, persistence, astm, projected, foundation, beginners, databases, machinery,
# Nearest to up: dealings, schwartz, docklands, assaulted, recite, rebus, recollections, counterexample,
# Nearest to or: plausible, side, card, ascertain, stuntman, franchises, whether, snuck,
# Nearest to is: seems, cessna, fulcrum, listing, switched, platform, better, define,
# Nearest to pope: illicit, ipo, ran, monkees, mesoderm, cry, st, tartaric,
# Nearest to orthodox: projectors, refrained, titan, burnaby, geochemistry, herbicides, wartime, mortal,
# Nearest to channel: truthfully, convenient, majority, hastily, impurity, ninth, jarmann, cash,
# Nearest to active: sintering, aggressive, caches, surviving, civilians, perses, crashes, hvv,
# Nearest to award: cohen, assert, backup, caster, discard, was, teslas, how,
# Nearest to primarily: selling, functions, treated, kcal, learners, preferring, encounter, rehabilitate,
# Nearest to cost: result, similarity, instated, cal, anomalies, punchline, winner, arose,
# Nearest to magazine: plotted, hyena, translate, parents, blueprint, ensure, synod, ekg,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9182 0.2234 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.8958 0.2282 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8665 0.2230 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8704 0.2203 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.7907 0.2195 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8252 0.2210 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.8049 0.2275 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7974 0.2346 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7928 0.2330 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7597 0.2221 sec/batch
# Nearest to this: gravity, panic, authorised, residing, stabilized, helpful, forcible, legitimacy,
# Nearest to but: affixed, stricter, equally, days, purposes, discover, implements, prominence,
# Nearest to d: constructors, ceded, uv, holloway, teachers, judgement, eugene, wadb,
# Nearest to to: inspect, promise, aesthetic, freak, vampyre, intercept, commercially, couch,
# Nearest to time: licensed, persistence, astm, projected, academics, mother, filter, foundation,
# Nearest to up: dealings, recollections, schwartz, poured, rebus, assaulted, docklands, counterexample,
# Nearest to or: plausible, stuntman, repeats, burr, card, ascertain, theologically, forbid,
# Nearest to is: fulcrum, cessna, switched, facilities, inductive, define, crypto, absurdity,
# Nearest to pope: illicit, ran, st, cry, monkees, neutrality, mesoderm, eight,
# Nearest to orthodox: refrained, projectors, titan, geochemistry, burnaby, wartime, church, herbicides,
# Nearest to channel: fermi, spot, inclusion, truthfully, hastily, kepler, grunge, geology,
# Nearest to active: surviving, sintering, caches, civilians, crashes, perses, diagnostic, awa,
# Nearest to award: assert, backup, cohen, caster, discard, was, teslas, hokku,
# Nearest to primarily: selling, learners, kcal, preferring, rehabilitate, functions, treated, loosely,
# Nearest to cost: result, cal, similarity, anomalies, thoroughbred, instated, punchline, terrorists,
# Nearest to magazine: translate, plotted, hyena, parents, alien, blueprint, ekg, ensure,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7719 0.2404 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7407 0.2414 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7101 0.2470 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7165 0.2251 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7447 0.2349 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.6953 0.2207 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7275 0.2178 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7043 0.2358 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7001 0.2264 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6520 0.2251 sec/batch
# Nearest to this: panic, gravity, authorised, stabilized, residing, helpful, legitimacy, theory,
# Nearest to but: affixed, stricter, implements, equally, mok, surgery, imply, embittered,
# Nearest to d: constructors, holloway, overlooks, b, industrialist, maclennan, fulda, ceded,
# Nearest to to: inspect, vampyre, aesthetic, arxiv, execution, vallejo, public, hort,
# Nearest to time: licensed, persistence, astm, academics, rearranged, mother, projected, taland,
# Nearest to up: dealings, recollections, schwartz, rebus, kaunda, poured, assaulted, link,
# Nearest to or: stuntman, plausible, repeats, burr, forbid, wholly, theologically, leased,
# Nearest to is: fulcrum, switched, absurdity, inductive, define, cessna, sprouted, crypto,
# Nearest to pope: st, illicit, cry, ran, ipo, mesoderm, eight, scrutinized,
# Nearest to orthodox: projectors, refrained, titan, geochemistry, burnaby, church, herbicides, wartime,
# Nearest to channel: jarmann, grunge, fermi, truthfully, spot, upn, receded, hastily,
# Nearest to active: sintering, awa, caches, jass, len, burgess, surviving, perses,
# Nearest to award: assert, backup, discard, cohen, caster, safi, hokku, was,
# Nearest to primarily: selling, learners, kcal, rehabilitate, preferring, treated, undetectable, discriminate,
# Nearest to cost: thoroughbred, result, anomalies, cal, similarity, punchline, ferns, instated,
# Nearest to magazine: plotted, translate, baz, hyena, softball, defensible, parents, austen,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6966 0.2219 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6703 0.2260 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6251 0.2164 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6156 0.2012 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6263 0.2083 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6283 0.2260 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.5823 0.1618 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5522 0.2222 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.4998 0.2232 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5041 0.2229 sec/batch
# Nearest to this: gravity, panic, stabilized, authorised, helpful, theory, precise, residing,
# Nearest to but: affixed, implements, stricter, mok, surgery, imply, salamis, equally,
# Nearest to d: b, industrialist, laureate, swiss, politician, psychologist, playwright, baron,
# Nearest to to: polyphony, inspect, freak, benchmark, aesthetic, vampyre, responsibilities, arxiv,
# Nearest to time: syntactically, rearranged, licensed, projected, filter, astm, mother, taland,
# Nearest to up: recollections, dealings, schwartz, poured, kaunda, rebus, link, assaulted,
# Nearest to or: stuntman, plausible, repeats, leased, ascertain, forbid, horrifying, ripple,
# Nearest to is: downfield, sprouted, fulcrum, define, absurdity, switched, facilities, crypto,
# Nearest to pope: st, illicit, herman, cry, eight, ipo, scrutinized, hollis,
# Nearest to orthodox: projectors, church, refrained, titan, geochemistry, burnaby, wartime, mortal,
# Nearest to channel: grunge, jarmann, fermi, truthfully, upn, inclusion, hastily, lds,
# Nearest to active: awa, len, jass, surviving, sintering, bengal, burgess, caches,
# Nearest to award: cohen, assert, discard, caster, safi, nomination, backup, laureate,
# Nearest to primarily: selling, learners, rehabilitate, kcal, landgrave, undetectable, destabilize, drugged,
# Nearest to cost: result, thoroughbred, anomalies, cal, ferns, similarity, punchline, instated,
# Nearest to magazine: joliot, plotted, defensible, baz, softball, alien, austen, parents,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.5002 0.2268 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4858 0.2242 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4474 0.2260 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5305 0.2222 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4943 0.2272 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4719 0.2223 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4669 0.2266 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.3865 0.2251 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4210 0.2273 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4387 0.2233 sec/batch
# Nearest to this: gravity, panic, stabilized, labored, precise, theory, helpful, join,
# Nearest to but: implements, stricter, affixed, abode, mok, equally, imply, salamis,
# Nearest to d: industrialist, psychologist, baron, holloway, constructors, overlooks, maclennan, b,
# Nearest to to: polyphony, inspect, ean, polaris, responsibilities, public, better, morphological,
# Nearest to time: syntactically, licensed, projected, rearranged, filter, taland, astm, spitzer,
# Nearest to up: recollections, dealings, poured, schwartz, rebus, kaunda, link, assaulted,
# Nearest to or: stuntman, plausible, ascertain, depend, object, repeats, leased, ripple,
# Nearest to is: define, downfield, fulcrum, sprouted, silico, disallows, boson, absurdity,
# Nearest to pope: st, illicit, hollis, cry, scrutinized, gillingham, huguenots, herman,
# Nearest to orthodox: church, projectors, refrained, geochemistry, titan, burnaby, mortal, christianity,
# Nearest to channel: jarmann, grunge, fermi, upn, inclusion, kona, spot, hastily,
# Nearest to active: awa, len, sintering, jass, bengal, caches, industrialized, ibo,
# Nearest to award: cohen, doug, caster, assert, nomination, safi, best, walter,
# Nearest to primarily: rehabilitate, selling, learners, kcal, cocker, treated, landgrave, undetectable,
# Nearest to cost: thoroughbred, result, anomalies, cal, costs, contingencies, instated, ferns,
# Nearest to magazine: joliot, defensible, plotted, parents, baz, ekg, austen, alien,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4365 0.2262 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4080 0.2180 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4329 0.2359 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3940 0.2201 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4092 0.2240 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4438 0.2451 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3621 0.2282 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3890 0.2274 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4024 0.2282 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3818 0.2272 sec/batch
# Nearest to this: panic, gravity, join, micros, stabilized, labored, goidelic, helpful,
# Nearest to but: abode, jen, consequently, diderot, salamis, isometry, stricter, implements,
# Nearest to d: industrialist, psychologist, holloway, b, overlooks, eugene, baron, playwright,
# Nearest to to: morphological, inspect, polaris, not, was, public, responsibilities, better,
# Nearest to time: syntactically, projected, licensed, filter, rearranged, astm, spitzer, contraindications,
# Nearest to up: recollections, poured, dealings, rebus, kaunda, schwartz, assaulted, renovations,
# Nearest to or: ascertain, plausible, stuntman, object, fraunhofer, repeats, depend, forbid,
# Nearest to is: define, downfield, fulcrum, disallows, boson, silico, sprouted, absurdity,
# Nearest to pope: st, illicit, huguenots, deposed, cry, gillingham, hollis, constantinople,
# Nearest to orthodox: church, christianity, refrained, projectors, catholic, geochemistry, christian, orthodoxy,
# Nearest to channel: jarmann, grunge, upn, fermi, kona, octagonal, doorstep, spot,
# Nearest to active: sintering, awa, len, jass, caches, industrialized, krishnan, aggressive,
# Nearest to award: nomination, cohen, best, doug, awards, caster, walter, laureate,
# Nearest to primarily: rehabilitate, learners, selling, kcal, landgrave, treated, undetectable, drugged,
# Nearest to cost: result, thoroughbred, costs, anomalies, cal, instated, ferns, contingencies,
# Nearest to magazine: joliot, parents, baz, ekg, plotted, defensible, kendall, biographies,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3409 0.2266 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3627 0.2276 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3901 0.2284 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3560 0.2264 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.4091 0.2255 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3928 0.2301 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3881 0.2270 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3836 0.2456 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3428 0.2272 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3390 0.2326 sec/batch
# Nearest to this: gravity, panic, join, micros, stabilized, unambiguous, goidelic, destructor,
# Nearest to but: isometry, consequently, diderot, implements, stricter, jen, affixed, orbited,
# Nearest to d: industrialist, psychologist, eugene, b, maclennan, overlooks, baron, holloway,
# Nearest to to: inspect, was, assurance, responsibilities, ean, morphological, obtainable, hierarchal,
# Nearest to time: syntactically, projected, gms, filter, contraindications, licensed, rearranged, spitzer,
# Nearest to up: recollections, poured, dealings, kaunda, rebus, schwartz, built, assaulted,
# Nearest to or: ascertain, plausible, forbid, repeats, fraunhofer, theologically, stuntman, homosexuals,
# Nearest to is: downfield, define, fulcrum, disallows, magellanic, absurdity, reflected, sprouted,
# Nearest to pope: constantinople, st, deposed, huguenots, illicit, gillingham, hollis, cry,
# Nearest to orthodox: church, christianity, refrained, projectors, orthodoxy, burnaby, titan, geochemistry,
# Nearest to channel: jarmann, grunge, upn, spot, octagonal, kona, fermi, doorstep,
# Nearest to active: caches, awa, sintering, jass, len, willfully, aggressive, krishnan,
# Nearest to award: best, awards, nomination, cohen, doug, caster, laureate, vance,
# Nearest to primarily: rehabilitate, learners, kcal, selling, treated, undetectable, pounded, drugged,
# Nearest to cost: costs, result, thoroughbred, anomalies, instated, cal, nighttime, distributing,
# Nearest to magazine: joliot, parents, baz, ekg, pages, biographies, alien, puget,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3141 0.2368 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2869 0.2359 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3710 0.2317 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3693 0.2332 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3795 0.2319 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2945 0.2296 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3286 0.2226 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3237 0.2230 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.1868 0.2264 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2778 0.2277 sec/batch
# Nearest to this: gravity, panic, join, micros, stabilized, destructor, unambiguous, precise,
# Nearest to but: isometry, consequently, orbited, diderot, implements, stricter, imply, abode,
# Nearest to d: industrialist, b, psychologist, statesman, baron, politician, holloway, maclennan,
# Nearest to to: inspect, assurance, was, responsibilities, bikinis, ean, hort, evangelica,
# Nearest to time: gms, syntactically, projected, contraindications, filter, rearranged, progressivism, licensed,
# Nearest to up: poured, recollections, kaunda, dealings, rebus, built, schwartz, assaulted,
# Nearest to or: ascertain, stuntman, fraunhofer, horrifying, homosexuals, plausible, repeats, ng,
# Nearest to is: downfield, define, absurdity, disallows, fulcrum, boson, transpiration, sprouted,
# Nearest to pope: constantinople, huguenots, excommunicated, gillingham, st, deposed, hollis, cardinals,
# Nearest to orthodox: church, refrained, projectors, christianity, geochemistry, titan, orthodoxy, denominations,
# Nearest to channel: jarmann, grunge, upn, kona, spot, octagonal, doorstep, fermi,
# Nearest to active: awa, caches, jass, willfully, aggressive, industrialized, sintering, krishnan,
# Nearest to award: best, awards, nomination, cohen, caster, morecambe, doug, vance,
# Nearest to primarily: rehabilitate, learners, kcal, selling, cultivated, undetectable, combatting, escalated,
# Nearest to cost: costs, result, thoroughbred, anomalies, instated, distributing, cal, eject,
# Nearest to magazine: joliot, baz, parents, biographies, pages, ekg, playground, characters,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3184 0.2275 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2711 0.2234 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3202 0.1036 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2794 0.2245 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2147 0.2304 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2222 0.2212 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2231 0.2265 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2648 0.2357 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2081 0.2354 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.2014 0.2316 sec/batch
# Nearest to this: gravity, join, micros, panic, destructor, stabilized, residing, unambiguous,
# Nearest to but: isometry, consequently, orbited, implements, pressburg, diderot, purposes, stricter,
# Nearest to d: statesman, baron, b, industrialist, psychologist, holloway, overlooks, politician,
# Nearest to to: inspect, was, responsibilities, assurance, ean, evangelica, saying, back,
# Nearest to time: syntactically, gms, projected, licensed, contraindications, filter, rearranged, spitzer,
# Nearest to up: poured, recollections, kaunda, dealings, rebus, built, assaulted, infusions,
# Nearest to or: ascertain, homosexuals, stuntman, fraunhofer, horrifying, vso, repeats, depend,
# Nearest to is: downfield, disallows, boson, icrm, magellanic, sprouted, fulcrum, transpiration,
# Nearest to pope: excommunicated, constantinople, huguenots, gillingham, hollis, deposed, cry, illicit,
# Nearest to orthodox: church, refrained, projectors, geochemistry, denominations, titan, christianity, mortal,
# Nearest to channel: jarmann, upn, grunge, kona, bits, octagonal, spot, doorstep,
# Nearest to active: caches, macroevolution, awa, willfully, jass, krishnan, sintering, industrialized,
# Nearest to award: best, awards, nomination, cohen, morecambe, vance, doug, caster,
# Nearest to primarily: rehabilitate, learners, selling, kcal, cultivated, italic, combatting, fertility,
# Nearest to cost: costs, thoroughbred, result, anomalies, cal, distributing, instated, eject,
# Nearest to magazine: joliot, baz, ekg, pages, playground, clarification, biographies, parents,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2377 0.2417 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2307 0.2384 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2118 0.2328 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1220 0.2230 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1503 0.2298 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1490 0.2220 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1406 0.2212 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1794 0.2290 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.2023 0.2183 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1957 0.2126 sec/batch
# Nearest to this: gravity, micros, unambiguous, join, stabilized, destructor, panic, labored,
# Nearest to but: isometry, consequently, orbited, implements, pebble, abode, purposes, pressburg,
# Nearest to d: cen, statesman, psychologist, b, industrialist, overlooks, holloway, baron,
# Nearest to to: inspect, was, saying, assurance, responsibilities, repeat, back, polaris,
# Nearest to time: syntactically, filter, gms, rearranged, contraindications, projected, licensed, voids,
# Nearest to up: poured, recollections, kaunda, dealings, rebus, infusions, assaulted, renovations,
# Nearest to or: ascertain, homosexuals, stuntman, fraunhofer, repeats, depend, do, insist,
# Nearest to is: downfield, disallows, boson, a, define, sprouted, magellanic, silico,
# Nearest to pope: excommunicated, constantinople, huguenots, gillingham, deposed, illicit, apostles, overthrowing,
# Nearest to orthodox: church, refrained, projectors, titan, denominations, geochemistry, mortal, nicene,
# Nearest to channel: upn, jarmann, kona, grunge, bits, octagonal, spot, eye,
# Nearest to active: macroevolution, sintering, caches, industrialized, locale, krishnan, awa, metabolite,
# Nearest to award: best, awards, nomination, cohen, vance, morecambe, caster, methylphenidate,
# Nearest to primarily: rehabilitate, learners, kcal, selling, cultivated, italic, bacilli, tallies,
# Nearest to cost: costs, thoroughbred, result, cal, distributing, contingencies, eject, anomalies,
# Nearest to magazine: joliot, baz, pages, biographies, ekg, parents, playground, clarification,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1495 0.2145 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2200 0.2256 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1829 0.2348 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1713 0.2394 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1713 0.2336 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.2055 0.2309 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1950 0.2276 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1769 0.2244 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1341 0.2205 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1667 0.2399 sec/batch
# Nearest to this: gravity, join, micros, unambiguous, panic, stabilized, precise, it,
# Nearest to but: isometry, consequently, abode, pebble, flatter, diderot, rosencrantz, implements,
# Nearest to d: statesman, b, industrialist, psychologist, cen, overlooks, baron, holloway,
# Nearest to to: inspect, was, saying, responsibilities, the, obtainable, evangelica, of,
# Nearest to time: gms, filter, syntactically, projected, contraindications, licensed, progressivism, rearranged,
# Nearest to up: poured, recollections, kaunda, infusions, dealings, renovations, rebus, assaulted,
# Nearest to or: ascertain, stuntman, fraunhofer, homosexuals, depend, repeats, burr, forbid,
# Nearest to is: downfield, disallows, a, boson, define, in, silico, magellanic,
# Nearest to pope: excommunicated, constantinople, huguenots, gillingham, deposed, overthrowing, st, isidor,
# Nearest to orthodox: church, refrained, titan, projectors, denominations, orthodoxy, creed, nicene,
# Nearest to channel: upn, jarmann, bits, grunge, kona, ensured, octagonal, spot,
# Nearest to active: macroevolution, sintering, jass, awa, caches, industrialized, willfully, diagnostic,
# Nearest to award: awards, best, nomination, cohen, vance, caster, morecambe, methylphenidate,
# Nearest to primarily: rehabilitate, learners, combatting, italic, selling, secessionist, nilotic, torrens,
# Nearest to cost: costs, thoroughbred, result, cal, distributing, wage, instated, terrorists,
# Nearest to magazine: joliot, biographies, baz, pages, parents, hyena, ekg, characters,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.2135 0.2504 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1678 0.2429 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1715 0.2383 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1944 0.2332 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1404 0.2344 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1356 0.2354 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1586 0.2339 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1221 0.2383 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1998 0.2463 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2071 0.2573 sec/batch
# Nearest to this: gravity, join, unambiguous, micros, stabilized, goidelic, destructor, subjugated,
# Nearest to but: isometry, consequently, princely, pressburg, affixed, defend, wouldn, salamis,
# Nearest to d: b, statesman, industrialist, psychologist, baron, holloway, swiss, cellist,
# Nearest to to: was, inspect, the, of, hort, saying, evangelica, remarriage,
# Nearest to time: gms, contraindications, progressivism, projected, filter, syntactically, bar, voids,
# Nearest to up: poured, recollections, dealings, kaunda, assaulted, rebus, infusions, renovations,
# Nearest to or: homosexuals, ascertain, burr, fraunhofer, stuntman, horrifying, forbid, vso,
# Nearest to is: downfield, a, disallows, icrm, dominates, in, sprouted, fulcrum,
# Nearest to pope: excommunicated, constantinople, st, huguenots, schism, recant, deposed, overthrowing,
# Nearest to orthodox: church, refrained, titan, projectors, geochemistry, contemporaneous, nicene, orthodoxy,
# Nearest to channel: upn, jarmann, bits, grunge, kona, ensured, octagonal, eye,
# Nearest to active: macroevolution, awa, jass, willfully, caches, sintering, diagnostic, krishnan,
# Nearest to award: best, awards, nomination, cohen, caster, vance, morecambe, won,
# Nearest to primarily: rehabilitate, learners, italic, combatting, nilotic, selling, patan, kcal,
# Nearest to cost: costs, thoroughbred, cal, result, anomalies, wage, instated, politic,
# Nearest to magazine: joliot, biographies, baz, parents, pages, characters, hyena, kendall,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2317 0.2322 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1301 0.2261 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1419 0.2179 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1086 0.2234 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0511 0.2440 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1504 0.2549 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1162 0.2445 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1467 0.2515 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1783 0.0447 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.0914 0.2327 sec/batch
# Nearest to this: gravity, unambiguous, join, micros, destructor, it, a, bulb,
# Nearest to but: isometry, consequently, orbited, purposes, pebble, pressburg, flatter, correlation,
# Nearest to d: b, statesman, psychologist, industrialist, holloway, swiss, baron, sergei,
# Nearest to to: inspect, the, was, of, send, saying, assurance, ensuring,
# Nearest to time: gms, filter, contraindications, projected, syntactically, bar, spitzer, progressivism,
# Nearest to up: poured, kaunda, recollections, infusions, dealings, assaulted, renovations, rebus,
# Nearest to or: homosexuals, ascertain, burr, fraunhofer, prions, repeats, stuntman, colonizer,
# Nearest to is: downfield, a, in, disallows, dominates, icrm, boson, rang,
# Nearest to pope: excommunicated, constantinople, huguenots, tipu, ladislaus, st, gillingham, surnamed,
# Nearest to orthodox: church, refrained, titan, projectors, geochemistry, contemporaneous, calvinists, compel,
# Nearest to channel: upn, jarmann, bits, grunge, kona, octagonal, eye, ensured,
# Nearest to active: macroevolution, jass, willfully, awa, diagnostic, industrialized, recommendations, caches,
# Nearest to award: awards, best, nomination, won, nominations, morecambe, academy, bafta,
# Nearest to primarily: rehabilitate, learners, italic, nilotic, combatting, selling, secessionist, patan,
# Nearest to cost: costs, thoroughbred, wage, cal, anomalies, result, usd, politic,
# Nearest to magazine: joliot, biographies, baz, parents, characters, pages, chickie, hyena,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0750 0.2360 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0745 0.2335 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.1005 0.2351 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0632 0.2351 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0573 0.2323 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0472 0.2319 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0865 0.2326 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0999 0.2363 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1165 0.2240 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0318 0.2275 sec/batch
# Nearest to this: gravity, unambiguous, a, join, micros, destructor, stabilized, it,
# Nearest to but: consequently, isometry, americans, pressburg, orbited, purposes, implements, flatter,
# Nearest to d: statesman, psychologist, sergei, industrialist, b, holloway, overlooks, baron,
# Nearest to to: the, inspect, send, was, of, back, expressway, assurance,
# Nearest to time: gms, filter, contraindications, bar, progressivism, rearranged, spitzer, voids,
# Nearest to up: poured, recollections, kaunda, infusions, dealings, renovations, rebus, assaulted,
# Nearest to or: homosexuals, ascertain, burr, stuntman, fraunhofer, colonizer, prions, whether,
# Nearest to is: a, in, downfield, disallows, dominates, united, boson, icrm,
# Nearest to pope: constantinople, excommunicated, deposed, huguenots, schism, surnamed, st, eugenius,
# Nearest to orthodox: church, refrained, titan, projectors, geochemistry, microcebus, contemporaneous, compel,
# Nearest to channel: upn, jarmann, bits, kona, eye, grunge, ensured, sdram,
# Nearest to active: macroevolution, caches, diagnostic, sintering, industrialized, jass, locale, krishnan,
# Nearest to award: awards, best, nomination, academy, nominations, cohen, won, morecambe,
# Nearest to primarily: learners, rehabilitate, selling, italic, patan, affordable, combatting, nilotic,
# Nearest to cost: costs, thoroughbred, cal, anomalies, result, politic, distributing, contingencies,
# Nearest to magazine: joliot, biographies, baz, chickie, clarification, parents, hyena, softball,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0370 0.2325 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0550 0.2321 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0047 0.2287 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0608 0.2283 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0694 0.2300 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0690 0.2295 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0715 0.2254 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1182 0.2030 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0588 0.2007 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0646 0.2014 sec/batch
# Nearest to this: a, unambiguous, gravity, micros, it, join, stabilized, solvable,
# Nearest to but: isometry, consequently, americans, purposes, rosencrantz, pebble, pressburg, princely,
# Nearest to d: statesman, cen, holloway, psychologist, sergei, resonate, overlooks, b,
# Nearest to to: the, inspect, of, saying, because, assurance, blackbody, send,
# Nearest to time: filter, gms, contraindications, rearranged, progressivism, projected, spitzer, voids,
# Nearest to up: poured, kaunda, recollections, infusions, dealings, renovations, usefully, assaulted,
# Nearest to or: homosexuals, ascertain, burr, fraunhofer, prions, stuntman, whether, do,
# Nearest to is: a, in, downfield, boson, homomorphism, disallows, dominates, the,
# Nearest to pope: constantinople, excommunicated, schism, huguenots, deposed, st, avignon, surnamed,
# Nearest to orthodox: church, refrained, titan, projectors, geochemistry, orthodoxy, microcebus, consubstantiation,
# Nearest to channel: upn, jarmann, bits, eye, multilevel, ensured, television, sdram,
# Nearest to active: macroevolution, industrialized, caches, sintering, peotone, diagnostic, willfully, recommendations,
# Nearest to award: awards, best, nomination, nominations, academy, won, caster, cohen,
# Nearest to primarily: learners, rehabilitate, combatting, patan, italic, selling, nilotic, affordable,
# Nearest to cost: costs, thoroughbred, cal, result, anomalies, politic, wage, distributing,
# Nearest to magazine: joliot, biographies, baz, characters, chickie, parents, hyena, barenaked,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0747 0.2014 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0931 0.2005 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0809 0.2013 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0578 0.1992 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0391 0.2010 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0720 0.2020 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0893 0.2004 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0525 0.2021 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0991 0.2005 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0860 0.2015 sec/batch
# Nearest to this: a, unambiguous, gravity, it, micros, join, stabilized, destructor,
# Nearest to but: consequently, isometry, americans, purposes, flatter, princely, rosencrantz, pressburg,
# Nearest to d: cen, statesman, overlooks, sergei, psychologist, holloway, teborg, wadb,
# Nearest to to: the, inspect, of, was, send, saying, shikoku, remarriage,
# Nearest to time: gms, filter, contraindications, progressivism, rearranged, voids, bar, spitzer,
# Nearest to up: poured, recollections, kaunda, infusions, dealings, usefully, renovations, eventually,
# Nearest to or: homosexuals, burr, ascertain, stuntman, whether, prions, vso, forbid,
# Nearest to is: a, dominates, downfield, in, disallows, boson, criollo, icrm,
# Nearest to pope: constantinople, excommunicated, huguenots, st, schism, deposed, avignon, cardinals,
# Nearest to orthodox: church, refrained, titan, projectors, orthodoxy, geochemistry, microcebus, contemporaneous,
# Nearest to channel: upn, jarmann, bits, ensured, broadcast, television, eye, multilevel,
# Nearest to active: macroevolution, caches, diagnostic, sintering, willfully, peotone, industrialized, jass,
# Nearest to award: awards, best, nomination, nominations, won, caster, bafta, academy,
# Nearest to primarily: learners, rehabilitate, combatting, italic, nilotic, patan, escalated, trotter,
# Nearest to cost: costs, thoroughbred, cal, politic, anomalies, unreliability, usd, result,
# Nearest to magazine: joliot, biographies, baz, characters, chickie, pages, playground, oldies,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0477 0.2044 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0102 0.2016 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0402 0.1996 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0756 0.2039 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0565 0.2023 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1079 0.2050 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1414 0.2032 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0423 0.2015 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0472 0.2037 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0510 0.1956 sec/batch
# Nearest to this: a, unambiguous, gravity, join, it, destructor, micros, stabilized,
# Nearest to but: consequently, isometry, americans, purposes, rosencrantz, princely, flatter, pressburg,
# Nearest to d: statesman, b, sergei, industrialist, cen, teborg, holloway, wadb,
# Nearest to to: the, inspect, send, assurance, saying, of, ensuring, was,
# Nearest to time: gms, filter, contraindications, projected, spitzer, bar, rearranged, progressivism,
# Nearest to up: poured, kaunda, recollections, dealings, infusions, renovations, usefully, unheard,
# Nearest to or: homosexuals, burr, stuntman, ascertain, colonizer, fraunhofer, whether, vso,
# Nearest to is: a, downfield, in, dominates, are, any, the, disallows,
# Nearest to pope: constantinople, excommunicated, huguenots, schism, st, avignon, cardinals, surnamed,
# Nearest to orthodox: church, refrained, titan, projectors, orthodoxy, geochemistry, microcebus, herbicides,
# Nearest to channel: upn, bits, jarmann, eye, multilevel, ensured, broadcast, sdram,
# Nearest to active: macroevolution, willfully, diagnostic, jass, caches, sintering, peotone, awa,
# Nearest to award: awards, best, nomination, nominations, won, academy, caster, bafta,
# Nearest to primarily: rehabilitate, learners, patan, combatting, nilotic, italic, selling, escalated,
# Nearest to cost: costs, thoroughbred, politic, cal, wage, anomalies, distributing, unreliability,
# Nearest to magazine: biographies, joliot, baz, chickie, playground, raimi, autodidacts, journal,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9854 0.1996 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0526 0.1977 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0529 0.1983 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0435 0.1959 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0822 0.1976 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0339 0.1819 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 3.9953 0.1982 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9912 0.1982 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0280 0.1973 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9741 0.1983 sec/batch
# Nearest to this: unambiguous, a, it, micros, destructor, gravity, stabilized, residing,
# Nearest to but: isometry, consequently, americans, purposes, flatter, pressburg, to, subfamilies,
# Nearest to d: statesman, b, sergei, psychologist, industrialist, wadb, holloway, swiss,
# Nearest to to: the, was, send, inspect, of, saying, because, so,
# Nearest to time: gms, filter, rearranged, projected, bar, spitzer, contraindications, voids,
# Nearest to up: poured, kaunda, recollections, dealings, usefully, infusions, renovations, unheard,
# Nearest to or: homosexuals, burr, whether, stuntman, hymen, colonizer, horrifying, prions,
# Nearest to is: a, in, dominates, downfield, are, the, of, icrm,
# Nearest to pope: excommunicated, constantinople, huguenots, surnamed, schism, avignon, xvi, st,
# Nearest to orthodox: church, refrained, titan, microcebus, projectors, geochemistry, orthodoxy, consubstantiation,
# Nearest to channel: upn, jarmann, bits, eye, ensured, broadcast, television, sdram,
# Nearest to active: macroevolution, diagnostic, willfully, cowes, industrialized, peotone, metabolite, jass,
# Nearest to award: awards, best, nomination, nominations, academy, bafta, won, nominated,
# Nearest to primarily: rehabilitate, learners, nilotic, patan, combatting, italic, escalated, citymayors,
# Nearest to cost: costs, politic, thoroughbred, cal, wage, distributing, usd, unreliability,
# Nearest to magazine: biographies, joliot, baz, chickie, clarification, journal, raimi, overhaul,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 4.0086 0.2010 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9391 0.1978 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0313 0.1969 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0316 0.1972 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0534 0.1979 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.9886 0.1980 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9435 0.1966 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9713 0.1975 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9523 0.1973 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9734 0.1982 sec/batch
# Nearest to this: unambiguous, a, it, micros, destructor, gravity, join, stabilized,
# Nearest to but: isometry, consequently, pressburg, americans, to, varepsilon, purposes, subfamilies,
# Nearest to d: sergei, wadb, statesman, cen, resonate, ceded, teborg, sy,
# Nearest to to: the, of, was, send, and, because, inspect, shikoku,
# Nearest to time: gms, filter, bar, rearranged, spitzer, projected, voids, progressivism,
# Nearest to up: recollections, poured, kaunda, infusions, unheard, usefully, dealings, tak,
# Nearest to or: homosexuals, stuntman, whether, burr, do, hock, umpire, colonizer,
# Nearest to is: a, in, are, the, of, dominates, downfield, which,
# Nearest to pope: excommunicated, constantinople, schism, xvi, huguenots, surnamed, deposed, cardinals,
# Nearest to orthodox: church, refrained, consubstantiation, microcebus, titan, orthodoxy, projectors, geochemistry,
# Nearest to channel: upn, eye, television, jarmann, bits, ensured, airing, broadcast,
# Nearest to active: macroevolution, peotone, diagnostic, sintering, cowes, caches, willfully, industrialized,
# Nearest to award: awards, best, nomination, nominations, academy, nominated, bafta, outstanding,
# Nearest to primarily: rehabilitate, patan, combatting, learners, trotter, italic, nilotic, hare,
# Nearest to cost: costs, politic, thoroughbred, cal, unreliability, anomalies, wage, usd,
# Nearest to magazine: biographies, joliot, baz, fanciful, chickie, clarification, raimi, pages,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 4.0142 0.1995 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.9830 0.1964 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9741 0.1948 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 3.9973 0.1965 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0478 0.1961 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9495 0.1968 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 4.0174 0.1973 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9959 0.1970 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9820 0.1966 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9749 0.1967 sec/batch
# Nearest to this: a, unambiguous, it, micros, editing, before, join, precise,
# Nearest to but: isometry, consequently, to, varepsilon, want, accepted, rosencrantz, americans,
# Nearest to d: statesman, b, sergei, wadb, teborg, industrialist, holloway, ceded,
# Nearest to to: the, was, of, send, and, inspect, emulated, so,
# Nearest to time: gms, filter, spitzer, warfield, progressivism, sitcoms, projected, cobb,
# Nearest to up: recollections, poured, kaunda, infusions, dealings, usefully, unheard, tak,
# Nearest to or: whether, homosexuals, stuntman, burr, forbid, do, fraunhofer, regressed,
# Nearest to is: a, in, the, are, dominates, of, any, downfield,
# Nearest to pope: constantinople, excommunicated, schism, xiii, xvi, surnamed, huguenots, deposed,
# Nearest to orthodox: church, refrained, orthodoxy, consubstantiation, titan, projectors, microcebus, contemporaneous,
# Nearest to channel: upn, eye, jarmann, ensured, television, bits, multilevel, airing,
# Nearest to active: macroevolution, peotone, cowes, diagnostic, sintering, compliance, caches, willfully,
# Nearest to award: awards, best, nomination, nominations, academy, nominated, bafta, outstanding,
# Nearest to primarily: rehabilitate, trotter, patan, combatting, nilotic, learners, hare, italic,
# Nearest to cost: costs, politic, thoroughbred, cal, distributing, unreliability, usd, wage,
# Nearest to magazine: biographies, joliot, baz, fanciful, chickie, publishing, journal, autodidacts,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 3.9859 0.2001 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 4.0013 0.1967 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 4.0061 0.1967 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 4.0187 0.1971 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0242 0.1971 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.9946 0.1967 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9603 0.1977 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9778 0.1967 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9863 0.1957 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0212 0.1973 sec/batch
# Nearest to this: unambiguous, a, it, micros, before, stabilized, datagram, gravity,
# Nearest to but: consequently, isometry, to, americans, correlation, accepted, flatter, subfamilies,
# Nearest to d: wadb, teborg, sergei, holloway, statesman, b, ceded, livres,
# Nearest to to: the, of, was, send, inspect, and, shikoku, but,
# Nearest to time: gms, projected, filter, progressivism, bar, contraindications, spitzer, sitcoms,
# Nearest to up: poured, kaunda, recollections, dealings, infusions, usefully, mommy, solidifies,
# Nearest to or: homosexuals, whether, stuntman, burr, forbid, do, vso, colonizer,
# Nearest to is: a, in, the, are, dominates, of, which, icrm,
# Nearest to pope: constantinople, excommunicated, schism, xvi, cardinals, xiii, huguenots, surnamed,
# Nearest to orthodox: church, refrained, consubstantiation, titan, orthodoxy, microcebus, herbicides, projectors,
# Nearest to channel: upn, eye, jarmann, bits, ensured, television, multilevel, broadcast,
# ...
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.8163 0.1969 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8983 0.1960 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.8822 0.1958 sec/batch
# Nearest to this: a, it, the, unambiguous, in, is, on, before,
# Nearest to but: to, that, be, among, was, however, not, they,
# Nearest to d: teborg, wadb, livres, hyakunin, sig, holloway, statesman, xenakis,
# Nearest to to: and, the, of, but, in, a, with, by,
# Nearest to time: gms, catastrophic, expect, trixie, equality, end, eunos, began,
# Nearest to up: kaunda, infusions, giedi, pressings, fretting, down, imagine, attained,
# Nearest to or: is, and, the, whether, a, as, to, of,
# Nearest to is: a, in, the, of, an, and, as, which,
# Nearest to pope: xvi, avignon, excommunicated, schism, hippolytus, cleric, monothelitism, conciliar,
# Nearest to orthodox: bulgaria, orthodoxy, microcebus, church, denominations, consubstantiation, herbicides, dobruja,
# Nearest to channel: upn, eye, broadcasting, multilevel, malory, television, channels, primarily,
# Nearest to active: repulsed, macroevolution, ghetto, malvinas, vertebrate, resupply, locations, rooftop,
# Nearest to award: awards, best, nominations, academy, nomination, nominated, awarded, outstanding,
# Nearest to primarily: smaller, an, hare, rehabilitate, channel, trotter, learners, patan,
# Nearest to cost: costs, cal, rebuilt, politic, punchline, harnad, shipping, recessions,
# Nearest to magazine: biographies, joliot, journals, journal, adoption, publishing, baz, playground,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8317 0.1996 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8753 0.1964 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8690 0.1961 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8484 0.1985 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8786 0.1959 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8891 0.1958 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8644 0.1963 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8447 0.1964 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8717 0.1963 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8449 0.1974 sec/batch
# Nearest to this: a, it, the, in, unambiguous, before, by, is,
# Nearest to but: to, was, be, and, consequently, however, that, not,
# Nearest to d: teborg, livres, wadb, hyakunin, saragossa, sig, ceded, sergei,
# Nearest to to: and, the, of, but, in, with, a, was,
# Nearest to time: catastrophic, gms, thaw, expect, sinusoidal, equality, end, polytechnique,
# Nearest to up: kaunda, giedi, infusions, pressings, attained, imagine, arranged, recollections,
# Nearest to or: is, whether, by, and, as, other, the, a,
# Nearest to is: a, in, of, the, and, which, an, as,
# Nearest to pope: xvi, excommunicated, avignon, schism, conciliar, constantinople, cleric, monothelitism,
# Nearest to orthodox: bulgaria, orthodoxy, church, denominations, consubstantiation, microcebus, herbicides, refrained,
# Nearest to channel: upn, eye, broadcasting, television, channels, malory, broadcast, bunting,
# Nearest to active: repulsed, macroevolution, ghetto, malvinas, patti, vertebrate, resupply, westinghouse,
# Nearest to award: awards, best, nomination, nominations, academy, nominated, awarded, outstanding,
# Nearest to primarily: an, smaller, rehabilitate, learners, channel, hare, trotter, shimei,
# Nearest to cost: costs, cal, rebuilt, politic, harnad, punchline, shipping, marginal,
# Nearest to magazine: joliot, journals, biographies, journal, publishing, adoption, baz, biography,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8853 0.1993 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8435 0.1955 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8375 0.1978 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8180 0.1945 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8979 0.1979 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8636 0.1976 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9725 0.1973 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8915 0.1963 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9092 0.1957 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8132 0.1965 sec/batch
# Nearest to this: a, it, the, is, before, in, unambiguous, and,
# Nearest to but: to, was, be, and, however, that, they, among,
# Nearest to d: statesman, livres, teborg, b, wadb, tenor, saragossa, sig,
# Nearest to to: and, the, of, but, with, in, was, a,
# Nearest to time: gms, catastrophic, thaw, noon, trixie, sitcoms, moulton, fertilizer,
# Nearest to up: kaunda, giedi, infusions, pressings, attained, imagine, sax, recollections,
# Nearest to or: is, whether, and, a, be, as, such, other,
# Nearest to is: a, in, the, of, an, and, it, or,
# Nearest to pope: xvi, excommunicated, avignon, schism, cleric, monothelitism, conciliar, hippolytus,
# Nearest to orthodox: bulgaria, orthodoxy, microcebus, denominations, church, consubstantiation, herbicides, dobruja,
# Nearest to channel: upn, eye, channels, broadcasting, multilevel, malory, television, bunting,
# Nearest to active: repulsed, macroevolution, ghetto, patti, malvinas, westinghouse, reese, renewal,
# Nearest to award: awards, best, nomination, nominations, academy, nominated, awarded, outstanding,
# Nearest to primarily: hare, rehabilitate, smaller, patan, an, domestic, learners, channel,
# Nearest to cost: costs, cal, punchline, harnad, rebuilt, politic, leia, recessions,
# Nearest to magazine: joliot, journals, biographies, adoption, journal, publishing, fired, defensible,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7927 0.1982 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8545 0.1956 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.8001 0.1981 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8983 0.1975 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8336 0.1980 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8695 0.1951 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.8937 0.1128 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8367 0.1980 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8545 0.1979 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8525 0.1966 sec/batch
# Nearest to this: a, it, the, been, unambiguous, in, before, on,
# Nearest to but: to, was, among, that, and, be, not, however,
# Nearest to d: statesman, b, teborg, livres, one, tenor, saragossa, wadb,
# Nearest to to: the, and, of, but, a, was, so, with,
# Nearest to time: catastrophic, gms, trixie, moulton, noon, thaw, end, grbac,
# Nearest to up: infusions, kaunda, giedi, down, attained, pressings, sax, poured,
# Nearest to or: is, whether, and, as, other, a, homosexuals, of,
# Nearest to is: a, in, of, the, an, as, it, and,
# Nearest to pope: xvi, excommunicated, avignon, cleric, schism, hippolytus, benedict, malleson,
# Nearest to orthodox: bulgaria, orthodoxy, microcebus, dobruja, herbicides, church, denominations, consubstantiation,
# Nearest to channel: upn, eye, channels, broadcasting, bunting, multilevel, airing, malory,
# Nearest to active: ghetto, repulsed, macroevolution, malvinas, gothicus, aggressive, resupply, reese,
# Nearest to award: awards, best, nominations, nomination, academy, nominated, outstanding, achievement,
# Nearest to primarily: smaller, hare, nilotic, rehabilitate, patan, targeting, learners, channel,
# Nearest to cost: costs, cal, harnad, marginal, rebuilt, punchline, leia, politic,
# Nearest to magazine: joliot, journals, adoption, biographies, journal, fired, publishing, defensible,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8355 0.2000 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8084 0.1971 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8362 0.1955 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.7925 0.1971 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8405 0.1972 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8292 0.1967 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8654 0.1980 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7413 0.1973 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8365 0.1981 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.8030 0.1979 sec/batch
# Nearest to this: a, it, is, unambiguous, the, in, before, be,
# Nearest to but: to, was, not, be, that, among, in, for,
# Nearest to d: wadb, livres, teborg, sig, saragossa, statesman, misdiagnosed, resonate,
# Nearest to to: and, the, of, but, with, so, a, other,
# Nearest to time: catastrophic, gms, end, sinusoidal, exist, monopolization, one, spitzer,
# Nearest to up: infusions, giedi, down, kaunda, number, pressings, imagine, attained,
# Nearest to or: is, and, as, other, of, for, to, the,
# Nearest to is: a, of, the, in, an, and, it, which,
# Nearest to pope: xvi, excommunicated, avignon, cleric, schism, benedict, hippolytus, conciliar,
# Nearest to orthodox: bulgaria, orthodoxy, microcebus, church, denominations, consubstantiation, dobruja, herbicides,
# Nearest to channel: upn, television, channels, eye, broadcasting, airing, pbs, broadcast,
# Nearest to active: repulsed, ghetto, macroevolution, resupply, malvinas, fuerzas, westinghouse, locations,
# Nearest to award: awards, best, nomination, nominations, academy, nominated, awarded, outstanding,
# Nearest to primarily: smaller, an, channel, hare, affiliate, targeting, patan, domestic,
# Nearest to cost: costs, rebuilt, harnad, cal, leia, punchline, windy, marginal,
# Nearest to magazine: joliot, journals, adoption, biographies, journal, publishing, initialism, hits,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7563 0.1987 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8170 0.1978 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8309 0.1974 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8231 0.1974 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8367 0.1959 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.9087 0.1973 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8467 0.1974 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8018 0.1966 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8550 0.1967 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8413 0.1975 sec/batch
# Nearest to this: a, it, in, the, is, before, unambiguous, still,
# Nearest to but: to, that, be, not, they, was, among, in,
# Nearest to d: teborg, livres, wadb, misdiagnosed, hyakunin, sig, saragossa, evangelische,
# Nearest to to: and, the, of, a, with, but, in, other,
# Nearest to time: catastrophic, second, end, gms, grbac, thaw, exist, began,
# Nearest to up: infusions, giedi, kaunda, number, imagine, attained, pressings, down,
# Nearest to or: is, a, the, by, as, other, and, whether,
# Nearest to is: a, the, in, of, an, and, as, or,
# Nearest to pope: xvi, schism, cleric, avignon, excommunicated, monothelitism, conciliar, constantinople,
# Nearest to orthodox: orthodoxy, bulgaria, church, denominations, microcebus, dobruja, consubstantiation, herbicides,
# Nearest to channel: upn, channels, eye, primarily, broadcasting, pbs, television, airing,
# Nearest to active: repulsed, macroevolution, ghetto, malvinas, fuerzas, resupply, include, locations,
# Nearest to award: awards, best, nominations, nomination, academy, nominated, outstanding, awarded,
# Nearest to primarily: smaller, an, channel, entirely, hare, viacom, trotter, affiliate,
# Nearest to cost: costs, harnad, rebuilt, cal, punchline, leia, marginal, usd,
# Nearest to magazine: journals, joliot, journal, biographies, publishing, adoption, initialism, playground,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8506 0.2001 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8562 0.1976 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8117 0.1981 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8453 0.1977 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8805 0.1967 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8309 0.1967 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8119 0.1961 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8560 0.1964 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8157 0.1969 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8426 0.1950 sec/batch
# Nearest to this: a, it, in, the, is, of, to, and,
# Nearest to but: to, that, be, they, and, not, was, as,
# Nearest to d: teborg, livres, wadb, misdiagnosed, sig, hyakunin, saragossa, evangelische,
# Nearest to to: and, the, of, a, in, with, other, by,
# Nearest to time: catastrophic, end, second, thaw, one, gms, rebounding, noon,
# Nearest to up: infusions, kaunda, to, giedi, imagine, number, just, pressings,
# Nearest to or: is, as, other, a, for, and, by, of,
# Nearest to is: a, in, the, of, and, an, as, it,
# Nearest to pope: xvi, schism, avignon, excommunicated, cleric, monothelitism, benedict, conciliar,
# Nearest to orthodox: orthodoxy, bulgaria, church, microcebus, denominations, dobruja, consubstantiation, geochemistry,
# Nearest to channel: upn, channels, broadcasting, pbs, eye, primarily, broadcast, terrestrial,
# Nearest to active: repulsed, macroevolution, malvinas, include, fuerzas, patti, resupply, westinghouse,
# Nearest to award: awards, best, nominations, nomination, academy, nominated, outstanding, awarded,
# Nearest to primarily: an, smaller, channel, entirely, learners, targeting, hare, rehabilitate,
# Nearest to cost: costs, cal, usd, harnad, windy, rebuilt, punchline, marginal,
# Nearest to magazine: journals, joliot, publishing, journal, biographies, adoption, magazines, playground,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8707 0.1992 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8275 0.1984 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9248 0.1990 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.9167 0.1971 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8880 0.1952 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8226 0.1978 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7705 0.1954 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8426 0.1965 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7220 0.1974 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8841 0.1968 sec/batch
# Nearest to this: a, it, the, is, on, before, in, been,
# Nearest to but: to, that, be, was, not, and, with, among,
# Nearest to d: statesman, teborg, b, hyakunin, tenor, xenakis, one, livres,
# Nearest to to: the, and, of, with, a, but, so, is,
# Nearest to time: catastrophic, end, gms, thaw, moulton, in, second, the,
# Nearest to up: infusions, kaunda, imagine, attained, sax, giedi, pressings, just,
# Nearest to or: is, as, a, of, other, by, for, and,
# Nearest to is: a, the, of, in, an, and, to, as,
# Nearest to pope: xvi, avignon, benedict, cleric, excommunicated, schism, hippolytus, monothelitism,
# Nearest to orthodox: bulgaria, orthodoxy, microcebus, church, dobruja, denominations, herbicides, geochemistry,
# Nearest to channel: upn, channels, primarily, bunting, pbs, eye, talia, broadcasting,
# Nearest to active: repulsed, malvinas, ghetto, macroevolution, patti, fuerzas, include, westinghouse,
# Nearest to award: awards, best, nomination, nominations, academy, nominated, outstanding, awarded,
# Nearest to primarily: smaller, an, channel, lankan, hare, patan, targeting, mostly,
# Nearest to cost: costs, marginal, harnad, usd, cal, alternatives, punchline, windy,
# Nearest to magazine: joliot, journals, adoption, publishing, fired, journal, biographies, playground,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8538 0.2008 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8278 0.1959 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
